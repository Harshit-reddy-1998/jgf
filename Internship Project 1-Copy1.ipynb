# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Users\\Harshit Reddy\\Downloads\\Data file.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# We have 209593 rows and 37 columns.

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %% [markdown]
# We have float type, int type, object values in independent variables.
# Label is our target variable where we have int values.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# Here, there are no missing values.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # To check correlation

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(dfcorr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# The two classes are not equally distributed. Here, the class imbalance exists.

# %%
df['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
# perform upscaling to address sample imbalance
from sklearn.utils import resample

# %%
# Here, I have done random over sampling as it increases the number of instances in the minority class.
# Separate majority and minority classes.
train_positive=df[df['label']==1]
train_negative=df[df['label']==0]

# Upsample minority class
train_negative_upsample=resample(train_negative,replace=True,n_samples=183431,random_state=18)

# Combine majority class with upsampled minority class
df1=pd.concat([train_positive,train_negative_upsample])

# Display new class counts
df1['label'].value_counts()
# Out:
# 1    183431
# 0    183431
# Name: label, dtype: int64

# %%
sns.countplot(df1['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df1
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# 5                6      1  35819I70783   568.0   2257.362667   2261.460000
# ...            ...    ...          ...     ...           ...           ...
# 74366        74367      0  27184I88680   797.0     11.776000     14.720000
# 51358        51359      0  61574I95201   352.0      1.306667      1.306667
# 203099      203100      0  50492I85328   429.0    600.000000    600.000000
# 118246      118247      0  08564I89239  1073.0     18.533333     22.266667
# 19212        19213      0  46256I82738   874.0     15.293333     15.293333
#
# ...

# %%
sns.distplot(df['aon'])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed in this column.

# %%
sns.distplot(df['daily_decr30'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
sns.distplot(df['daily_decr90'])
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
sns.distplot(df['rental30'])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %%
sns.distplot(df['rental90'])
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sns.distplot(df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sns.distplot(df['last_rech_date_da'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Density'>

# %%
sns.distplot(df['last_rech_amt_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Density'>

# %%
sns.distplot(df['cnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['fr_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['medianmarechprebal30'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Density'>

# %%
sns.distplot(df['cnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['sumamnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['medianmarechprebal90'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %%
sns.distplot(df['cnt_da_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='Density'>

# %%
sns.distplot(df['fr_da_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='Density'>

# %%
sns.distplot(df['cnt_da_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90', ylabel='Density'>

# %%
sns.distplot(df['fr_da_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='Density'>

# %%
sns.distplot(df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['cnt_loans90'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['maxamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['payback30'])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Density'>

# %%
sns.distplot(df['payback90'])
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %%
df.skew()
# Out:
# Unnamed: 0               0.000000
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# ...

# %%
import numpy as np
df['aon']=np.cbrt(df['aon'])
sns.distplot(df['aon'])
df['aon'].skew()
# Out:
# 8.740118054611601

# %%
df['cnt_ma_rech30']=np.cbrt(df['cnt_ma_rech90'])
sns.distplot(df['cnt_ma_rech30'])
df['cnt_ma_rech30'].skew()
# Out:
# -0.33895791653905344

# %%
df['daily_decr30']=np.cbrt(df['daily_decr30'])
sns.distplot(df['daily_decr30'])
df['daily_decr30'].skew()
# Out:
# 0.5381159618092636

# %%
df['daily_decr90']=np.cbrt(df['daily_decr90'])
sns.distplot(df['daily_decr90'])
df['daily_decr90'].skew()
# Out:
# 0.6076074745680442

# %%
import numpy as np
df['rental30']=np.cbrt(df['rental30'])
sns.distplot(df['rental30'])
df['rental30'].skew()
# Out:
# 0.0841654157154998

# %%
df['rental90']=np.cbrt(df['rental90'])
sns.distplot(df['rental90'])
df['rental90'].skew()
# Out:
# 0.1732893976758105

# %%
df['last_rech_date_ma']=np.cbrt(df['last_rech_date_ma'])
sns.distplot(df['last_rech_date_ma'])
df['last_rech_date_ma'].skew()
# Out:
# 13.755534520734777

# %%
df['last_rech_date_da']=np.cbrt(df['last_rech_date_da'])
sns.distplot(df['last_rech_date_da'])
df['last_rech_date_da'].skew()
# Out:
# 14.001041955144418

# %%
df['last_rech_amt_ma']=np.cbrt(df['last_rech_amt_ma'])
sns.distplot(df['last_rech_amt_ma'])
df['last_rech_amt_ma'].skew()
# Out:
# -0.40195412057502283

# %%
df['cnt_ma_rech30']=np.cbrt(df['cnt_ma_rech30'])
sns.distplot(df['cnt_ma_rech30'])
df['cnt_ma_rech30'].skew()
# Out:
# -2.181917923153636

# %%
df['fr_ma_rech30']=np.cbrt(df['fr_ma_rech30'])
sns.distplot(df['fr_ma_rech30'])
df['fr_ma_rech30'].skew()
# Out:
# 13.69584534326012

# %%
df['sumamnt_ma_rech30']=np.cbrt(df['sumamnt_ma_rech30'])
sns.distplot(df['sumamnt_ma_rech30'])
df['sumamnt_ma_rech30'].skew()
# Out:
# -0.21305995935709443

# %%
df['medianamnt_ma_rech30']=np.cbrt(df['medianamnt_ma_rech30'])
sns.distplot(df['medianamnt_ma_rech30'])
df['medianamnt_ma_rech30'].skew()
# Out:
# -0.5402651746327146

# %%
df['medianmarechprebal30']=np.cbrt(df['medianmarechprebal30'])
sns.distplot(df['medianmarechprebal30'])
df['medianmarechprebal30'].skew()
# Out:
# 11.57825224400747

# %%
df['cnt_ma_rech90']=np.cbrt(df['cnt_ma_rech90'])
sns.distplot(df['cnt_ma_rech90'])
df['cnt_ma_rech90'].skew()
# Out:
# -0.33895791653905344

# %%
df['fr_ma_rech90']=np.cbrt(df['fr_ma_rech90'])
sns.distplot(df['fr_ma_rech90'])
df['fr_ma_rech90'].skew()
# Out:
# 0.3623600225801717

# %%
df['sumamnt_ma_rech90']=np.cbrt(df['sumamnt_ma_rech90'])
sns.distplot(df['sumamnt_ma_rech90'])
df['sumamnt_ma_rech90'].skew()
# Out:
# -0.01652953946902665

# %%
df['medianamnt_ma_rech90']=np.cbrt(df['medianamnt_ma_rech90'])
sns.distplot(df['medianamnt_ma_rech90'])
df['medianamnt_ma_rech90'].skew()
# Out:
# -0.5074625412529152

# %%
df['medianmarechprebal90']=np.cbrt(df['medianmarechprebal90'])
sns.distplot(df['medianmarechprebal90'])
df['medianmarechprebal90'].skew()
# Out:
# 0.5090848308317113

# %%
df['cnt_da_rech30']=np.cbrt(df['cnt_da_rech30'])
sns.distplot(df['cnt_da_rech30'])
df['cnt_da_rech30'].skew()
# Out:
# 14.792314034079054

# %%
df['fr_da_rech30']=np.cbrt(df['fr_da_rech30'])
sns.distplot(df['fr_da_rech30'])
df['fr_da_rech30'].skew()
# Out:
# 14.127590071823947

# %%
df['cnt_da_rech90']=np.cbrt(df['cnt_da_rech90'])
sns.distplot(df['cnt_da_rech90'])
df['cnt_da_rech90'].skew()
# Out:
# 6.670255441463707

# %%
df['fr_da_rech90']=np.cbrt(df['fr_da_rech90'])
sns.distplot(df['fr_da_rech90'])
df['fr_da_rech90'].skew()
# Out:
# 17.539626778460395

# %%
df['cnt_loans30']=np.cbrt(df['cnt_loans30'])
sns.distplot(df['cnt_loans30'])
df['cnt_loans30'].skew()
# Out:
# 0.2691007873717979

# %%
df['amnt_loans30']=np.cbrt(df['amnt_loans30'])
sns.distplot(df['amnt_loans30'])
df['amnt_loans30'].skew()
# Out:
# 0.3453741198688776

# %%
df['maxamnt_loans30']=np.cbrt(df['maxamnt_loans30'])
sns.distplot(df['maxamnt_loans30'])
df['maxamnt_loans30'].skew()
# Out:
# 14.597060605014958

# %%
df['medianamnt_loans30']=np.cbrt(df['medianamnt_loans30'])
sns.distplot(df['medianamnt_loans30'])
df['medianamnt_loans30'].skew()
# Out:
# 3.5581777653412585

# %%
df['cnt_loans90']=np.cbrt(df['cnt_loans90'])
sns.distplot(df['cnt_loans90'])
df['cnt_loans90'].skew()
# Out:
# 10.411644333051933

# %%
df['amnt_loans90']=np.cbrt(df['amnt_loans90'])
sns.distplot(df['amnt_loans90'])
df['amnt_loans90'].skew()
# Out:
# 0.7477262186536714

# %%
df['maxamnt_loans90']=np.cbrt(df['maxamnt_loans90'])
sns.distplot(df['maxamnt_loans90'])
df['maxamnt_loans90'].skew()
# Out:
# -3.6987960398673234

# %%
df['medianamnt_loans90']=np.cbrt(df['medianamnt_loans90'])
sns.distplot(df['medianamnt_loans90'])
df['medianamnt_loans90'].skew()
# Out:
# 3.892717341068507

# %%
df['payback30']=np.cbrt(df['payback30'])
sns.distplot(df['payback30'])
df['payback30'].skew()
# Out:
# 0.7451906275675773

# %%
df['payback90']=np.cbrt(df['payback90'])
sns.distplot(df['payback90'])
df['payback90'].skew()
# Out:
# 0.6319528603258964

# %%
plt.boxplot(df['aon'])
plt.show()

# %%
plt.boxplot(df['daily_decr30'])
plt.show()

# %%
plt.boxplot(df['daily_decr90'])
plt.show()

# %%
plt.boxplot(df['rental30'])
plt.show()

# %%
plt.boxplot(df['rental90'])
plt.show()

# %%
plt.boxplot(df['last_rech_date_ma'])
plt.show()

# %%
plt.boxplot(df['last_rech_date_da'])
plt.show()

# %%
plt.boxplot(df['last_rech_amt_ma'])
plt.show()

# %%
plt.boxplot(df['cnt_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['fr_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['sumamnt_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['medianamnt_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['medianmarechprebal30'])
plt.show()

# %%
plt.boxplot(df['cnt_ma_rech90'])
plt.show()

# %%
plt.boxplot(df['fr_ma_rech90'])
plt.show()

# %%
plt.boxplot(df['sumamnt_ma_rech90'])
plt.show()

# %%
plt.boxplot(df['medianamnt_ma_rech90'])
plt.show()

# %%
plt.boxplot(df['medianmarechprebal90'])
plt.show()

# %%
plt.boxplot(df['cnt_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['fr_ma_rech30'])
plt.show()

# %%
plt.boxplot(df['cnt_da_rech90'])
plt.show()

# %%
plt.boxplot(df['fr_da_rech90'])
plt.show()

# %%
plt.boxplot(df['cnt_loans30'])
plt.show()

# %%
plt.boxplot(df['amnt_loans30'])
plt.show()

# %%
plt.boxplot(df['maxamnt_loans90'])
plt.show()

# %%
plt.boxplot(df['medianamnt_loans90'])
plt.show()

# %%
plt.boxplot(df['payback30'])
plt.show()

# %%
plt.boxplot(df['payback90'])
plt.show()
